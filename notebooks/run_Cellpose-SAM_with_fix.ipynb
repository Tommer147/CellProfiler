# %% [markdown]
# <a href="https://colab.research.google.com/github/Tommer147/CellProfiler/blob/main/notebooks/run_Cellpose-SAM_with_fix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Then click on "Folder" icon on the Left, press the refresh button. Your Google Drive folder should now be available here as "gdrive".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-yv5vacio
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-yv5vacio
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit 17fb25f40055ec2636aa708dc4cf6625b8b4735d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2025.10.16)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (4.67.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (0.24.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (4.12.0.88)
# Requirement already satisfied: fastremap in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (1.17.7)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2025.11.11)
# Requirement already satisfied: roifile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2025.5.10)
# Requirement already satisfied: fill-voids in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2.1.1)
# Requirement already satisfied: segment_anything in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (1.0)
# Requirement already satisfied: torch==2.9.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.8) (2.9.0+cu126)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.8) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.0->torchvision->cellpose==4.0.8) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.0->torchvision->cellpose==4.0.8) (3.0.3)

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

model = models.CellposeModel(gpu=True)
# Out:
# 2025-12-06 18:21:46,568 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2025-12-06 18:21:46,569 [INFO]
# cellpose version: 	4.0.8
# platform:       	linux
# python version: 	3.12.12
# torch version:  	2.9.0+cu126
# 2025-12-06 18:21:46,571 [INFO] ** TORCH CUDA version installed and working. **
# 2025-12-06 18:21:46,573 [INFO] ** TORCH CUDA version installed and working. **
# 2025-12-06 18:21:46,574 [INFO] >>>> using GPU (CUDA)
# 2025-12-06 18:21:48,754 [INFO] >>>> loading model /root/.cellpose/models/cpsam

# %% [markdown]
# Input directory with your images:

# %%
# *** change to your google drive folder path ***
dir = "/content/drive/MyDrive/Merge_BFcolor/BFcolor"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".tif"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 206 images in folder:
# Cisplatin_T1_Day3_2_20251126.tif
# Cisplatin_T1_Day3_4_20251126.tif
# Cisplatin_T1_Day3_6_20251126.tif
# Cisplatin_T1_Day3_8_20251126.tif
# Cisplatin_T1_Day3_10_20251126.tif
# Cisplatin_T1_Day3_12_20251126.tif
# Cisplatin_T1_Day3_14_20251126.tif
# Cisplatin_T1_Day3_16_20251126.tif
# Cisplatin_T1_Day3_18_20251126.tif
# Cisplatin_T1_Day3_20_20251126.tif
# Cisplatin_T1_Day7_2_20251126.tif
# Cisplatin_T1_Day7_4_20251126.tif
# Cisplatin_T1_Day7_6_20251126.tif
# Cisplatin_T1_Day7_8_20251126.tif
# Cisplatin_T1_Day7_10_20251126.tif
# Cisplatin_T1_Day7_12_20251126.tif
# Cisplatin_T1_Day7_14_20251126.tif
# Cisplatin_T1_Day7_16_20251126.tif
# Cisplatin_T1_Day7_18_20251126.tif
# Cisplatin_T1_Day7_20_20251126.tif
# Cisplatin_T1_Day10_2_20251126.tif
# Cisplatin_T1_Day10_4_20251126.tif
# Cisplatin_T1_Day10_6_20251126.tif
# Cisplatin_T1_Day10_8_20251126.tif
# Cisplatin_T1_Day10_10_20251126.tif
# Cisplatin_T1_Day10_12_20251126.tif
# Cisplatin_T1_Day10_14_20251126.tif
# Cisplatin_T1_Day10_16_20251126.tif
# Cisplatin_T1_Day10_18_20251126.tif
# Cisplatin_T1_Day10_20_20251126.tif
# Cisplatin_T1_Day14_2_20251126.tif
# Cisplatin_T1_Day14_4_20251126.tif
# Cisplatin_T1_Day14_6_20251126.tif
# Cisplatin_T1_Day14_8_20251126.tif
# Cisplatin_T1_Day14_10_20251126.tif
# Cisplatin_T1_Day14_12_20251126.tif
# Cisplatin_T1_Day14_14_20251126.tif
# Cisplatin_T1_Day14_16_20251126.tif
# Cisplatin_T1_Day14_18_20251126.tif
# Cisplatin_T1_Day14_20_20251126.tif
# Cisplatin_T3_Day3_2_20251126.tif
# Xray_Day7_16_20251126.tif
# Xray_Day7_18_20251126.tif
# Xray_Day7_20_20251126.tif
# Xray_Day10_2_20251126.tif
# Xray_Day10_4_20251126.tif
# Xray_Day10_6_20251126.tif
# Xray_Day10_8_20251126.tif
# Xray_Day10_10_20251126.tif
# Xray_Day10_12_20251126.tif
# Xray_Day10_14_20251126.tif
# Xray_Day10_16_20251126.tif
# Xray_Day10_18_20251126.tif
# Xray_Day10_20_20251126.tif
# Xray_Day14_2_20251126.tif
# Xray_Day14_4_20251126.tif
# Xray_Day14_6_20251126.tif
# Xray_Day14_8_20251126.tif
# Xray_Day14_10_20251126.tif
# Xray_Day14_12_20251126.tif
# Xray_Day14_14_20251126.tif
# Xray_Day14_16_20251126.tif
# Xray_Day14_18_20251126.tif
# Xray_Day14_20_20251126.tif

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (1024, 1360, 3). Assuming channel dimension is last with 3 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = '2' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]


flow_threshold = 4
cellprob_threshold = -3.6
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img_selected_channels, masks, flows[0])
plt.tight_layout()
plt.show()
# Out:
# 2025-12-06 18:37:50,036 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:38:03,219 [WARNING] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1253..3605].
# 2025-12-06 18:38:04,526 [WARNING] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0..3589].

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# 100%|██████████| 206/206 [00:11<00:00, 18.42it/s]
# running cellpose-SAM
# 2025-12-06 18:38:31,295 [INFO] 0%|          | 0/206 [00:00<?, ?it/s]
# 2025-12-06 18:38:31,303 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:38:43,923 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:38:56,899 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:39:10,000 [INFO] 1%|1         | 3/206 [00:38<43:38, 12.90s/it]
# 2025-12-06 18:39:10,003 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:39:22,533 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:39:28,825 [INFO] 1%|1         | 3/206 [00:57<43:38, 12.90s/it]
# 2025-12-06 18:39:34,724 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:39:46,837 [INFO] 3%|2         | 6/206 [01:15<41:46, 12.53s/it]
# 2025-12-06 18:39:46,841 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:39:58,827 [INFO] 3%|2         | 6/206 [01:27<41:46, 12.53s/it]
# 2025-12-06 18:39:59,018 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:40:11,355 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:40:24,034 [INFO] 4%|4         | 9/206 [01:52<40:57, 12.47s/it]
# 2025-12-06 18:40:24,037 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:40:36,658 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:40:38,833 [INFO] 4%|4         | 9/206 [02:07<40:57, 12.47s/it]
# 2025-12-06 18:40:49,657 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:41:02,728 [INFO] 6%|5         | 12/206 [02:31<40:52, 12.64s/it]
# 2025-12-06 18:41:02,731 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:41:15,595 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:41:18,836 [INFO] 6%|5         | 12/206 [02:47<40:52, 12.64s/it]
# 2025-12-06 18:41:28,696 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:41:41,608 [INFO] 7%|7         | 15/206 [03:10<40:36, 12.76s/it]
# 2025-12-06 18:41:41,612 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:41:54,449 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18:41:58,840 [INFO] 7%|7         | 15/206 [03:27<40:36, 12.76s/it]
# 2025-12-06 18:42:07,628 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 18
[INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:20:03,982 [INFO] 92%|#########1| 189/206 [41:32<03:39, 12.93s/it]
# 2025-12-06 19:20:03,985 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:20:16,826 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:20:19,019 [INFO] 92%|#########1| 189/206 [41:47<03:39, 12.93s/it]
# 2025-12-06 19:20:29,543 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:20:42,331 [INFO] 93%|#########3| 192/206 [42:11<03:00, 12.89s/it]
# 2025-12-06 19:20:42,334 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:20:55,445 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:20:59,022 [INFO] 93%|#########3| 192/206 [42:27<03:00, 12.89s/it]
# 2025-12-06 19:21:08,409 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:21:21,836 [INFO] 95%|#########4| 195/206 [42:50<02:22, 12.97s/it]
# 2025-12-06 19:21:21,839 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:21:34,920 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:21:39,026 [INFO] 95%|#########4| 195/206 [43:07<02:22, 12.97s/it]
# 2025-12-06 19:21:47,633 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:22:00,687 [INFO] 96%|#########6| 198/206 [43:29<01:43, 12.96s/it]
# 2025-12-06 19:22:00,690 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:22:13,414 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:22:19,028 [INFO] 96%|#########6| 198/206 [43:47<01:43, 12.96s/it]
# 2025-12-06 19:22:26,590 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:22:39,576 [INFO] 98%|#########7| 201/206 [44:08<01:04, 12.96s/it]
# 2025-12-06 19:22:39,580 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:22:52,961 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:22:59,030 [INFO] 98%|#########7| 201/206 [44:27<01:04, 12.96s/it]
# 2025-12-06 19:23:05,802 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:23:19,395 [INFO] 99%|#########9| 204/206 [44:48<00:26, 13.06s/it]
# 2025-12-06 19:23:19,399 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:23:32,678 [INFO] processing image with (1024, 1360) HW, and 3 channels
# 2025-12-06 19:23:39,035 [INFO] 99%|#########9| 204/206 [45:07<00:26, 13.06s/it]
# 2025-12-06 19:23:45,626 [INFO] 100%|##########| 206/206 [45:14<00:00, 13.18s/it]
# saving masks
# 100%|██████████| 206/206 [00:04<00:00, 42.92it/s]

# %% [markdown]
# to save your masks for ImageJ, run the following code:

# %%
for i in trange(len(files)):
    f = files[i]
    # Save the masks to a file (io.imsave returns None)
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
    # Pass the actual mask data (masks[i]) to save ROIs
    io.save_rois(masks[i], f)
# Out:
#  12%|█▏        | 24/206 [00:14<01:55,  1.57it/s]
# empty outlines found, saving 224 ImageJ ROIs to .zip archive.
#  32%|███▏      | 66/206 [00:40<01:22,  1.69it/s]
# empty outlines found, saving 159 ImageJ ROIs to .zip archive.
#  34%|███▍      | 71/206 [00:44<01:35,  1.42it/s]
# empty outlines found, saving 218 ImageJ ROIs to .zip archive.
#  36%|███▌      | 74/206 [00:46<01:31,  1.44it/s]
# empty outlines found, saving 207 ImageJ ROIs to .zip archive.
#  50%|████▉     | 102/206 [01:14<02:12,  1.27s/it]
# empty outlines found, saving 669 ImageJ ROIs to .zip archive.
#  75%|███████▍  | 154/206 [04:24<04:46,  5.51s/it]
# empty outlines found, saving 3038 ImageJ ROIs to .zip archive.
# 100%|██████████| 206/206 [06:02<00:00,  1.76s/it]
